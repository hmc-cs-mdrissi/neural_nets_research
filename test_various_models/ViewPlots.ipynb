# %%
# cd ..

# %%
import matplotlib.pyplot as plt
import os

# %%
plot_every = 100
suffix = "accuracy.txt"
matching_files = []
files = [f for f in os.listdir('.') if os.path.isfile(f)]
for name in files:
    if name[-len(suffix):] == suffix:
        matching_files.append(name[:-len(suffix)])
print(matching_files)

for filename in matching_files:

    with open(filename + "loss.txt") as f:
        print(filename)
#         print(f.read().split(","))
        points = [float(x) for x in f.read().split(",")[:-1]]

    plt.plot([x * plot_every for x in range(len(points))], points)
    plt.title(filename + "loss")
    plt.show()

    with open(filename + "accuracy.txt") as f:
        points = [float(x) for x in f.read().split(",")[:-1]]

    plt.plot([x * plot_every for x in range(len(points))], points)
    plt.title(filename + "accuracy")
    plt.show()
# Out:
# ['sequence_0_train_', 'grammar_0_val_', 'sequence_1_val_', 'tree_1_train_', 'grammar_0_train_', 'sequence_0_val_', 'tree_1_val_', 'sequence_1_train_', 'tree_0_train_', 'tree_0_val_', 'grammar_1_train_', 'grammar_1_val_']
# sequence_0_train_
# grammar_0_val_
# sequence_1_val_
# tree_1_train_
# grammar_0_train_
# sequence_0_val_
# tree_1_val_
# sequence_1_train_
# tree_0_train_
# tree_0_val_
# grammar_1_train_
# grammar_1_val_

# %%
with open("t2s-normal-vars-train.txt") as f:
    points = [float(x) for x in f.readlines()]

plt.plot([x * plot_every for x in range(len(points))], points)
plt.title("t2s-normal-vars-train")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5c229be42734> in <module>()
# ----> 1 with open("t2s-normal-vars-train.txt") as f:
#       2     points = [float(x) for x in f.readlines()]
#       3
#       4 plt.plot([x * plot_every for x in range(len(points))], points)
#       5 plt.title("t2s-normal-vars-train")
#
# FileNotFoundError: [Errno 2] No such file or directory: 't2s-normal-vars-train.txt'
